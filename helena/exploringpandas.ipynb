# %%
import numpy as np 
import pandas as pd

#can I only visualize one thing per code block?

train = pd.read_csv("cc-est2022-all.csv", encoding='iso-8859-1')
df = train.copy()

# %%
df.head() #see first 5 rows
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50      1       1  Alabama  Autauga County     1       0    58802
# 1      50      1       1  Alabama  Autauga County     1       1     3443
# 2      50      1       1  Alabama  Autauga County     1       2     3613
# 3      50      1       1  Alabama  Autauga County     1       3     4131
# 4      50      1       1  Alabama  Autauga County     1       4     3963
#
#    TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# 0     28761       30041  ...        854          734        112           97
# 1      1790        1653  ...         83           54         14            9
# 2      1849        1764  ...         81           68          5            8
# 3      2121        2010  ...         81           81         10           10
# 4      2003        1960  ...         72           70          8            9
#
# ...

# %%
df.tail() #see last 5 rows
# Out:
#         SUMLEV  STATE  COUNTY   STNAME        CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 238939      50     56      45  Wyoming  Weston County     4      14      590
# 238940      50     56      45  Wyoming  Weston County     4      15      415
# 238941      50     56      45  Wyoming  Weston County     4      16      254
# 238942      50     56      45  Wyoming  Weston County     4      17      141
# 238943      50     56      45  Wyoming  Weston County     4      18      170
#
#         TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  \
# 238939       323         267  ...          5            7          0
# 238940       231         184  ...          6            5          0
# 238941       127         127  ...          2            0          0
# 238942        71          70  ...          1            1          0
# 238943        58         112  ...          0            2          0
#
#         HBAC_FEMALE  HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  \
# ...

# %%
#df.shape() #n samples x n features 
#df.columns() #columns
df.describe() #general data about the dataset
# Out:
#          SUMLEV          STATE         COUNTY           YEAR         AGEGRP  \
# count  238944.0  238944.000000  238944.000000  238944.000000  238944.000000
# mean       50.0      30.264313     103.874046       2.500000       9.000000
# std         0.0      15.150290     107.549646       1.118036       5.477237
# min        50.0       1.000000       1.000000       1.000000       0.000000
# 25%        50.0      18.000000      35.000000       1.750000       4.000000
# 50%        50.0      29.000000      79.000000       2.500000       9.000000
# 75%        50.0      45.000000     133.500000       3.250000      14.000000
# max        50.0      56.000000     840.000000       4.000000      18.000000
#
#             TOT_POP      TOT_MALE    TOT_FEMALE       WA_MALE     WA_FEMALE  \
# count  2.389440e+05  2.389440e+05  2.389440e+05  2.389440e+05  2.389440e+05
# mean   1.111792e+04  5.516226e+03  5.601694e+03  4.207822e+03  4.215769e+03
# ...

# %%
#what is a dataframe? - own snippet of data
df_empty = pd.DataFrame()
demographics_dict = {'County':['Dupage'], 'Race':['White']}
df_demographics = pd.DataFrame(demographics_dict).reset_index(drop=True)
df_demographics.head()
# Out:
#    County   Race
# 0  Dupage  White

# %%
#selecting some columns
needs=df[['WA_FEMALE','WA_MALE','CTYNAME','TOT_POP']]
needs.head()

#numerical columns
#what does this do?
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df_num = df.select_dtypes(include=numerics)

#categorical columns
df_cat = df.select_dtypes(include=['object'])

# %%
#slicing, not just 5 with head()
#doesn't display, but makes smaller list
#can cut down on only columns I want
#can I index further than just start and end?
df_sub1=df.iloc[0:100,:] #first 100 rows, all columns
df_sub2=df.iloc[:250,[1,8]] #columns at specified indices
#iloc only takes integers as indices 
df_sub1.head()
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50      1       1  Alabama  Autauga County     1       0    58802
# 1      50      1       1  Alabama  Autauga County     1       1     3443
# 2      50      1       1  Alabama  Autauga County     1       2     3613
# 3      50      1       1  Alabama  Autauga County     1       3     4131
# 4      50      1       1  Alabama  Autauga County     1       4     3963
#
#    TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# 0     28761       30041  ...        854          734        112           97
# 1      1790        1653  ...         83           54         14            9
# 2      1849        1764  ...         81           68          5            8
# 3      2121        2010  ...         81           81         10           10
# 4      2003        1960  ...         72           70          8            9
#
# ...

# %%
'''
columns:
sum of male and female to find total in county
WA white alone
BA black/african american alone
IA american indian & alaska native alone
AA asian alone
NA native hawaiian and other pasific islander alone
H hispanic 
TOM 2 or more races pop
*adding a C to race means "or in combination" ?

state numerical 1-50 by alphabetical
 -- county alphabetical from within that
'''

#modifying columns
#df['column']=df['column'].map({"value":new value, "value": new value})
df.head()

#delete columns
#df=df.drop(['ColumnName'],axis=1)

#split function can split columns for each

def findWhiteFemale(females, population):
    if females > (0.5 * population): 
        return 1
    else:
        return 0
#how can i combine WA_FEMALE and WA_MALE to have white pop?
df['WHITEF']=df['WA_FEMALE', 'TOT_POP'].apply(lambda x: findWhiteFemale(x))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('WA_FEMALE', 'TOT_POP')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#for county, slice all white and all not white
   #must combine male and female
#determine what is majority in county

#combine male and female for each demographic type
df_white=df[(df['WA_MALE']>0) & (df['WA_FEMALE']>0)]
